# %%
import csv
with open('ipv4_addresses.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['IPv4'])
    
    for B in range(2, 198):
        for C in range(1, 201):
            ipv4_address = f"250.{B}.{C}.0"
            writer.writerow([ipv4_address])

# %%
import csv

with open('ipv4_addresses_all_sets2.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['SET1', 'SET2', 'SET3', 'SET4', 'SET5', 'SET6', 'SET7', 'SET8', 'SET9', 'SET10', 'SET11', 'SET12', 'SET13'])
    
    for B in range(150, 298):
        for C in range(1, 201):
            set1 = f"250.{B}.{C}.0"
            set2 = f"250.{B + 1}.{C}.0"
            set3 = f"250.{B + 2}.{C}.0"
            set4 = f"250.{B + 3}.{C}.0"
            set5 = f"250.{B + 4}.{C}.0"
            set6 = f"250.{B + 5}.{C}.0"
            set7 = f"250.{B + 6}.{C}.0"
            set8 = f"250.{B + 7}.{C}.0"
            set9 = f"250.{B + 8}.{C}.0"
            set10 = f"250.{B + 9}.{C}.0"
            set11 = f"250.{B + 10}.{C}.0"
            set12 = f"250.{B + 11}.{C}.0"
            set13 = f"250.{B + 12}.{C}.0"
            writer.writerow([set1, set2, set3, set4, set5, set6, set7, set8, set9, set10, set11, set12, set13])

# %%
import csv

with open('ipv6_addresses_all_sets2.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['SET1', 'SET2', 'SET3', 'SET4', 'SET5', 'SET6', 'SET7', 'SET8', 'SET9', 'SET10', 'SET11', 'SET12', 'SET13', 'SET14', 'SET15', 'SET16'])
    
    for B in range(150, 298):
        for C in range(1, 41):
            set1 = f"3000:0:{B}:{C}::"
            set2 = f"3000:0:{B + 1}:{C}::"
            set3 = f"3000:0:{B + 2}:{C}::"
            set4 = f"3000:0:{B + 3}:{C}::"
            set5 = f"3000:0:{B + 4}:{C}::"
            set6 = f"3000:0:{B + 5}:{C}::"
            set7 = f"3000:0:{B + 6}:{C}::"
            set8 = f"3000:0:{B + 7}:{C}::"
            set9 = f"3000:0:{B + 8}:{C}::"
            set10 = f"3000:0:{B + 9}:{C}::"
            set11 = f"3000:0:{B + 10}:{C}::"
            set12 = f"3000:0:{B + 11}:{C}::"
            set13 = f"3000:0:{B + 12}:{C}::"
            set14 = f"3000:0:{B + 13}:{C}::"
            set15 = f"3000:0:{B + 14}:{C}::"
            set16 = f"3000:0:{B + 15}:{C}::"
            writer.writerow([set1, set2, set3, set4, set5, set6, set7, set8, set9, set10, set11, set12, set13, set14, set15, set16])

# %%
for B in range(2, 198):
    for C in range(1, 201):
        ipv4_address = f"250.{B}.{C}.0"
        print(ipv4_address)
